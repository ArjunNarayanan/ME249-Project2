# %%
'''>>>>> start CodeP2.2
    V.P. Carey ME249, Spring 2021

Intro to Neural Network Modeling 
Keras model for comparison with first principles model'''

#import useful packages
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf

#the follwoing 2 lines are only needed for Mac OS machines
# import os
# os.environ['KMP_DUPLICATE_LIB_OK']='True'

#raw data in dictionary form x01, x02, x03, y3
my_dict = { 
    'x01' : [20., 20., 20., 20.2, 20., 20.2, 24.0, 36.],
    'x02' : [13., 14.5, 15.3, 13., 14.5, 15.3, 13., 14.5],
    'x03' : [310.8, 308.0, 306.0, 310.8, 308.0, 306.0, 310.8, 308.0],
    'y3' : [30.97, 32.3, 31.5, 30.91, 32.5, 31.4, 35.59, 46.4]
}
#normalized inputs in array
xdata = []
xdata = [[20./20.2, 13.0/14.5, 310.8/308.0], [20./20.2, 14.5/14.5, 308.0/308.0]] 
xdata.append([20./20.2, 15.3/14.5, 306.0/308.0])
xdata.append([20.2/20.2, 13.0/14.5, 310.8/308.0]) 
xdata.append([20./20.2, 14.5/14.5, 308.0/308.0]) 
xdata.append([20.2/20.2, 15.3/14.5, 306.0/308.0]) 
xdata.append([24./20.2, 13.0/14.5, 310.8/308.0]) 
xdata.append([36./20.2, 14.5/14.5, 308.0/308.0]) 
#data frame
df = pd.DataFrame(my_dict)
#devide by the median to normalize 
df.x01= df.x01/20.2
df.x02= df.x02/14.5
df.x03= df.x03/308.0
#normalize output array
df.y3= df.y3/32.401
df.head
print (df.x01, df.x02, df.x03, df.y3)

xarray= np.array(xdata)
print (xdata)
print (xarray)
# Out:
# Using TensorFlow backend.
# 0    0.990099
# 1    0.990099
# 2    0.990099
# 3    1.000000
# 4    0.990099
# 5    1.000000
# 6    1.188119
# 7    1.782178
# Name: x01, dtype: float64 0    0.896552
# 1    1.000000
# 2    1.055172
# 3    0.896552
# 4    1.000000
# 5    1.055172
# 6    0.896552
# 7    1.000000
# Name: x02, dtype: float64 0    1.009091
# 1    1.000000
# 2    0.993506
# 3    1.009091
# 4    1.000000
# 5    0.993506
# 6    1.009091
# 7    1.000000
# Name: x03, dtype: float64 0    0.955835
# 1    0.996883
# 2    0.972192
# 3    0.953983
# 4    1.003055
# 5    0.969106
# 6    1.098423
# 7    1.432055
# Name: y3, dtype: float64
# [[0.9900990099009901, 0.896551724137931, 1.009090909090909], [0.9900990099009901, 1.0, 1.0], [0.9900990099009901, 1.0551724137931036, 0.9935064935064936], [1.0, 0.896551724137931, 1.009090909090909], [0.9900990099009901, 1.0, 1.0], [1.0, 1.0551724137931036, 0.9935064935064936], [1.188118811881188, 0.896551724137931, 1.009090909090909], [1.7821782178217822, 1.0, 1.0]]
# [[0.99009901 0.89655172 1.00909091]
#  [0.99009901 1.         1.        ]
#  [0.99009901 1.05517241 0.99350649]
#  [1.         0.89655172 1.00909091]
#  [0.99009901 1.         1.        ]
#  [1.         1.05517241 0.99350649]
#  [1.18811881 0.89655172 1.00909091]
#  [1.78217822 1.         1.        ]]

# %%
# define model

#As seen below, we have created three dense layers each with just one neuron. 
#A dense layer is a layer in neural network that’s fully connected. 
#In other words, all the neurons in one layer are connected to all other neurons in the next layer.
#In the first layer, we need to provide the input shape, which is 3 in this case. 
#The activation function we have chosen is ReLU, which stands for rectified linear unit.

from keras import backend as K
#initialize weights with values between -0.2 and 1.2
initializer = tf.keras.initializers.RandomUniform(minval= -0.2, maxval=1.2)

# define three layer model with one neuron in each layer
model = keras.Sequential([
    keras.layers.Dense(4, activation=K.elu, input_shape=[3]),
    keras.layers.Dense(4, activation=K.elu),
    keras.layers.Dense(1, activation=K.elu)
  ])

# %%
#We’re using RMSprop as our optimizer here. RMSprop stands for Root Mean Square Propagation. 
#It’s one of the most popular gradient descent optimization algorithms for deep learning networks. 
#RMSprop is an optimizer that’s reliable and fast.
#We’re compiling the mode using the model.compile function. The loss function used here 
#is mean absolute error. After the compilation of the model, we’ll use the fit method with 100 epochs.

#Running model.fit successive times extends the calculation to addtional epochs.

sgd = tf.keras.optimizers.RMSprop(learning_rate=0.003)
model.compile(loss='mean_absolute_error',optimizer=sgd)

# %%
#After the compilation of the model, we’ll use the fit method with 500 epochs.
#I started with epochs value of 100 and then tested the model after training. 
#The prediction was not that good. Then I modified the number of epochs to 200 and tested the model again. 
#Accuracy had improved slightly, but figured I’d give it one more try. Finally, at 500 epochs 
#I found acceptable prediction accuracy.

#The fit method takes three parameters; namely, x, y, and number of epochs. 
#During model training, if all the batches of data are seen by the model once, 
#we say that one epoch has been completed.

model.fit(xarray,df.y3,epochs=100)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0807
# Epoch 2/100
# 8/8 [==============================] - 0s 411us/step - loss: 0.0802
# Epoch 3/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0778
# Epoch 4/100
# 8/8 [==============================] - 0s 633us/step - loss: 0.0768
# Epoch 5/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0759
# Epoch 6/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0750
# Epoch 7/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0741
# Epoch 8/100
# 8/8 [==============================] - 0s 707us/step - loss: 0.0732
# Epoch 9/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0723
# Epoch 10/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0715
# Epoch 11/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0706
# Epoch 12/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0697
# Epoch 13/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0688
# Epoch 14/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0679
# Epoch 15/100
# 8/8 [==============================] - 0s 760us/step - loss: 0.0669
# Epoch 16/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0660
# Epoch 17/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0650
# Epoch 18/100
# 8/8 [==============================] - 0s 595us/step - loss: 0.0640
# Epoch 19/100
# 8/8 [==============================] - 0s 712us/step - loss: 0.0630
# Epoch 20/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0620
# Epoch 21/100
# 8/8 [==============================] - 0s 701us/step - loss: 0.0610
# Epoch 22/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 23/100
# 8/8 [==============================] - 0s 570us/step - loss: 0.0592
# Epoch 24/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0622
# Epoch 25/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0584
# Epoch 26/100
# 8/8 [==============================] - 0s 772us/step - loss: 0.0566
# Epoch 27/100
# 8/8 [==============================] - 0s 432us/step - loss: 0.0557
# Epoch 28/100
# 8/8 [==============================] - 0s 458us/step - loss: 0.0548
# Epoch 29/100
# 8/8 [==============================] - 0s 591us/step - loss: 0.0539
# Epoch 30/100
# 8/8 [==============================] - 0s 538us/step - loss: 0.0530
# Epoch 31/100
# 8/8 [==============================] - 0s 829us/step - loss: 0.0520
# Epoch 32/100
# 8/8 [==============================] - 0s 497us/step - loss: 0.0510
# Epoch 33/100
# 8/8 [==============================] - 0s 625us/step - loss: 0.0500
# Epoch 34/100
# 8/8 [==============================] - 0s 420us/step - loss: 0.0490
# Epoch 35/100
# 8/8 [==============================] - 0s 408us/step - loss: 0.0480
# Epoch 36/100
# 8/8 [==============================] - 0s 740us/step - loss: 0.0469
# Epoch 37/100
# 8/8 [==============================] - 0s 709us/step - loss: 0.0458
# Epoch 38/100
# 8/8 [==============================] - 0s 701us/step - loss: 0.0480
# Epoch 39/100
# 8/8 [==============================] - 0s 354us/step - loss: 0.0473
# Epoch 40/100
# 8/8 [==============================] - 0s 692us/step - loss: 0.0435
# Epoch 41/100
# 8/8 [==============================] - 0s 746us/step - loss: 0.0426
# Epoch 42/100
# 8/8 [==============================] - 0s 464us/step - loss: 0.0416
# Epoch 43/100
# 8/8 [==============================] - 0s 566us/step - loss: 0.0406
# Epoch 44/100
# 8/8 [==============================] - 0s 529us/step - loss: 0.0396
# Epoch 45/100
# 8/8 [==============================] - 0s 732us/step - loss: 0.0386
# Epoch 46/100
# 8/8 [==============================] - 0s 480us/step - loss: 0.0375
# Epoch 47/100
# 8/8 [==============================] - 0s 402us/step - loss: 0.0365
# Epoch 48/100
# 8/8 [==============================] - 0s 464us/step - loss: 0.0354
# Epoch 49/100
# 8/8 [==============================] - 0s 502us/step - loss: 0.0342
# Epoch 50/100
# 8/8 [==============================] - 0s 561us/step - loss: 0.0331
# Epoch 51/100
# 8/8 [==============================] - 0s 706us/step - loss: 0.0319
# Epoch 52/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0307
# Epoch 53/100
# 8/8 [==============================] - 0s 733us/step - loss: 0.0295
# Epoch 54/100
# 8/8 [==============================] - 0s 581us/step - loss: 0.0282
# Epoch 55/100
# 8/8 [==============================] - 0s 557us/step - loss: 0.0270
# Epoch 56/100
# 8/8 [==============================] - 0s 441us/step - loss: 0.0260
# Epoch 57/100
# 8/8 [==============================] - 0s 583us/step - loss: 0.0362
# Epoch 58/100
# 8/8 [==============================] - 0s 512us/step - loss: 0.0313
# Epoch 59/100
# 8/8 [==============================] - 0s 499us/step - loss: 0.0236
# Epoch 60/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 61/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0225
# Epoch 62/100
# 8/8 [==============================] - 0s 740us/step - loss: 0.0223
# Epoch 63/100
# 8/8 [==============================] - 0s 746us/step - loss: 0.0212
# Epoch 64/100
# 8/8 [==============================] - 0s 803us/step - loss: 0.0211
# Epoch 65/100
# 8/8 [==============================] - 0s 392us/step - loss: 0.0199
# Epoch 66/100
# 8/8 [==============================] - 0s 328us/step - loss: 0.0198
# Epoch 67/100
# 8/8 [==============================] - 0s 515us/step - loss: 0.0245
# Epoch 68/100
# 8/8 [==============================] - 0s 468us/step - loss: 0.0236
# Epoch 69/100
# 8/8 [==============================] - 0s 561us/step - loss: 0.0190
# Epoch 70/100
# 8/8 [==============================] - 0s 452us/step - loss: 0.0172
# Epoch 71/100
# 8/8 [==============================] - 0s 518us/step - loss: 0.0177
# Epoch 72/100
# 8/8 [==============================] - 0s 538us/step - loss: 0.0161
# Epoch 73/100
# 8/8 [==============================] - 0s 788us/step - loss: 0.0184
# Epoch 74/100
# 8/8 [==============================] - 0s 989us/step - loss: 0.0233
# Epoch 75/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0228
# Epoch 76/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0164
# Epoch 77/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0166
# Epoch 78/100
# 8/8 [==============================] - 0s 474us/step - loss: 0.0223
# Epoch 79/100
# 8/8 [==============================] - 0s 355us/step - loss: 0.0211
# Epoch 80/100
# 8/8 [==============================] - 0s 469us/step - loss: 0.0167
# Epoch 81/100
# 8/8 [==============================] - 0s 743us/step - loss: 0.0158
# Epoch 82/100
# 8/8 [==============================] - 0s 442us/step - loss: 0.0157
# Epoch 83/100
# 8/8 [==============================] - 0s 954us/step - loss: 0.0226
# Epoch 84/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0157
# Epoch 85/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0166
# Epoch 86/100
# 8/8 [==============================] - 0s 524us/step - loss: 0.0223
# Epoch 87/100
# 8/8 [==============================] - 0s 619us/step - loss: 0.0212
# Epoch 88/100
# 8/8 [==============================] - 0s 948us/step - loss: 0.0160
# Epoch 89/100
# 8/8 [==============================] - 0s 693us/step - loss: 0.0157
# Epoch 90/100
# 8/8 [==============================] - 0s 590us/step - loss: 0.0221
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0203
# Epoch 92/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 93/100
# 8/8 [==============================] - 0s 624us/step - loss: 0.0151
# Epoch 94/100
# 8/8 [==============================] - 0s 438us/step - loss: 0.0222
# Epoch 95/100
# 8/8 [==============================] - 0s 770us/step - loss: 0.0196
# Epoch 96/100
# 8/8 [==============================] - 0s 477us/step - loss: 0.0166
# Epoch 97/100
# 8/8 [==============================] - 0s 559us/step - loss: 0.0146
# Epoch 98/100
# 8/8 [==============================] - 0s 983us/step - loss: 0.0162
# Epoch 99/100
# 8/8 [==============================] - 0s 549us/step - loss: 0.0211
# Epoch 100/100
# 8/8 [==============================] - 0s 643us/step - loss: 0.0161

# %%
# from __future__ import print_function
#For results of training network:

#keras.layer.get_weights() function retrieves weight values
first_layer_weights = model.layers[0].get_weights()[0]
w01 = first_layer_weights[0][0]
w02 = first_layer_weights[1][0]
w03 = first_layer_weights[2][0]
first_layer_bias  = model.layers[0].get_weights()[1]
b1 = first_layer_bias
second_layer_weights = model.layers[1].get_weights()[0]
w12 = second_layer_weights[0][0]
second_layer_bias  = model.layers[1].get_weights()[1]
b2 = second_layer_bias
third_layer_weights = model.layers[2].get_weights()[0]
w23 = third_layer_weights[0][0]
third_layer_bias  = model.layers[2].get_weights()[1]
b3 = third_layer_bias

#print weights and biases
print (first_layer_weights)
print ('w01 = ', w01, 'w02 = ', w02, 'w03 = ', w03)
print (first_layer_bias)
print ('b1 = ', b1)
print (second_layer_weights)
print ('w12 = ', w12)
print (second_layer_bias)
print ('b2 = ', b2)
print (third_layer_weights)
print ('w23 = ', w23)
print (third_layer_bias)
print ('b3 = ', b3)

#use model.predict() function to print model predictions for data conditions
xarray= np.array(xdata)
print ('x01/20.2,  x02/14.5,   x03/308.0,  y3/32.4,  a3:')
test = []
for i in range(0,8): 
    test = [[xarray[i][0], xarray[i][1], xarray[i][2]]]
    testarray = np.array(test)
    a3 = model.predict(testarray)
    print (xarray[i][0], xarray[i][1], xarray[i][2], df.y3[i], a3)
print('  ')
print ('x01,  x02,   x03,  y3,  a3*32.4:')
for i in range(0,8): 
    test = [[xarray[i][0], xarray[i][1], xarray[i][2]]]
    testarray = np.array(test)
    a3 = model.predict(testarray)
    print (xarray[i][0]*20.2, xarray[i][1]*14.5, xarray[i][2]*308.0, df.y3[i]*32.4, a3*32.4)
# Out:
# [[-0.5546382  -0.33132634  1.3338982  -2.3136754 ]
#  [-0.78900415  0.00339559 -0.04200174 -1.6776005 ]
#  [-1.3649417  -0.02423315 -0.04164204 -2.0827448 ]]
# w01 =  -0.5546382 w02 =  -0.78900415 w03 =  -1.3649417
# [-0.44586802  0.4186515  -0.7936948  -1.856011  ]
# b1 =  [-0.44586802  0.4186515  -0.7936948  -1.856011  ]
# [[ 0.02345913  0.24678303  1.7479653   1.4780577 ]
#  [ 0.38615236 -0.09244318  2.4384959   1.039276  ]
#  [-0.50902224  1.0566386  -1.1039048  -1.5330113 ]
#  [ 0.22729892  0.43058276  1.465031    0.561297  ]]
# w12 =  0.023459125
# [ 0.6620204   0.29805145 -1.06413    -0.7666336 ]
# b2 =  [ 0.6620204   0.29805145 -1.06413    -0.7666336 ]
# [[-0.23016934]
#  [ 0.26560754]
#  [ 0.3100079 ]
#  [-1.2639132 ]]
# w23 =  -0.23016934
# [0.09667291]
# b3 =  [0.09667291]
# x01/20.2,  x02/14.5,   x03/308.0,  y3/32.4,  a3:
# 0.9900990099009901 0.896551724137931 1.009090909090909 0.9558346964599856 [[0.9871613]]
# 0.9900990099009901 1.0 1.0 0.9968828122588808 [[0.98523796]]
# 0.9900990099009901 1.0551724137931036 0.9935064935064936 0.9721922162896206 [[0.984238]]
# 1.0 0.896551724137931 1.009090909090909 0.9539829017622912 [[0.9937461]]
# 0.9900990099009901 1.0 1.0 1.003055461251196 [[0.98523796]]
# 1.0 1.0551724137931036 0.9935064935064936 0.9691058917934631 [[0.99082655]]
# 1.188118811881188 0.896551724137931 1.009090909090909 1.0984228881824636 [[1.1150246]]
# 1.7821782178217822 1.0 1.0 1.4320545662170918 [[1.4496303]]
#
# x01,  x02,   x03,  y3,  a3*32.4:
# 20.0 13.0 310.8 30.969044165303533 [[31.984028]]
# 20.0 14.5 308.0 32.29900311718774 [[31.921711]]
# 20.0 15.3 306.0 31.499027807783705 [[31.889313]]
# 20.2 13.0 310.8 30.909046017098234 [[32.197376]]
# 20.0 14.5 308.0 32.498996944538746 [[31.921711]]
# 20.2 15.3 306.0 31.3990308941082 [[32.102783]]
# 23.999999999999996 13.0 310.8 35.58890157711182 [[36.126797]]
# 36.0 14.5 308.0 46.398567945433776 [[46.96802]]

# %%
# Out:
# [<keras.layers.core.Dense at 0x7facacd94630>,
#  <keras.layers.core.Dense at 0x7facacd7ef98>,
#  <keras.layers.core.Dense at 0x7facacd7ea90>]
